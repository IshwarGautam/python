# %% [markdown]
# # See location and image with tkinter

# %%
import tkinter as tk
from tkinter import *
from tkinter import messagebox
from PIL import Image, ImageTk
import cv2

# %%
window=tk.Tk()
window.title("Project")
window.resizable(0,0)

load1 = Image.open("title.png")
photo1 = ImageTk.PhotoImage(load1)

header = tk.Button(window, image=photo1)
header.place(x=5,y=0)


canvas1 = Canvas(window,width=500, height=250, bg='ivory')
canvas1.place(x=5,y=120)                


canvas2 = Canvas(window,width=500, height=270, bg="orange")
canvas2.place(x=5,y=380) 

canvas3 = Canvas(window,width=280, height=530, bg="green")
canvas3.place(x=515,y=120)


l1=tk.Button(canvas1,text="Name",font=("Algerian",15), bg="white", fg="green")
l1.place(x=5,y=5)
t1=tk.Entry(canvas1,width=50,bd=5)
t1.place(x=150,y=10)

l2=tk.Button(canvas1,text="Profession",font=("Algerian",15),bg="white", fg="green")
l2.place(x=5,y=50)
t2=tk.Entry(canvas1,width=50,bd=5)
t2.place(x=150,y=55)

l3=tk.Button(canvas1,text="Age",font=("Algerian",15),bg="white", fg="green")
l3.place(x=5,y=100)
t3=tk.Entry(canvas1,width=50,bd=5)
t3.place(x=150,y=105)

def see_location():
    canvas2 = Canvas(window,width=500, height=270, bg="orange")
    canvas2.place(x=5,y=380)
    
    if(t1.get()=="Priyanka Chopra" and t2.get()=="Actress" and t3.get()=="38"):
        import webbrowser 
        webbrowser.open('https://www.google.com/maps/place/Beverly Hills') 

        import time
        time.sleep(10)

        import pyautogui
        myScreenshot = pyautogui.screenshot(region=(600,300,500,300))
        myScreenshot.save('location.jpg')

        load = Image.open("location.jpg")
        photo = ImageTk.PhotoImage(load)
        img = Label(canvas2, image=photo, width=500, height=270)
        img.image = photo
        img.place(x=0, y=0)
        
    else:
        btn = tk.Button(canvas2, text="Sorry, you are not allowed to see the location")
        btn.place(x=0, y=0)
        
b1=tk.Button(canvas1,text="See location",font=("Algerian",20),bg='white',fg='red',command=see_location)
b1.place(x=10,y=180)

def see_image():
    canvas3 = Canvas(window,width=280, height=530, bg="green")
    canvas3.place(x=515,y=120)
    if(t1.get()=="Priyanka Chopra" and t2.get()=="Actress" and t3.get()=="38"):
        load = Image.open("priyanka.jpg")
        photo = ImageTk.PhotoImage(load)
        img = Label(canvas3, image=photo, width=280, height=530)
        img.image = photo
        img.place(x=0, y=5)

    else:
        btn = tk.Button(canvas3, text="Sorry, you are not allowed to see the image")
        btn.place(x=0, y=5)
        


    
b2=tk.Button(canvas1,text="See Image",font=("Algerian",20),bg='pink',fg='black',command=see_image)
b2.place(x=255,y=180)



    

window.geometry("800x680")
window.mainloop()

# %% [markdown]
# # Handwritten digit recognition (Not completed.....)

# %%
import tkinter as tk
from tkinter import *
from tkinter import messagebox
from PIL import Image,ImageTk

window=tk.Tk()
window.title("Project")
window.resizable(0,0)



load1 = Image.open("hdr.png")
photo1 = ImageTk.PhotoImage(load1)

header = tk.Button(window, image=photo1)
header.place(x=5,y=0)

canvas1 = Canvas(window,width=500, height=250, bg='ivory')
canvas1.place(x=5,y=120)                

canvas2 = Canvas(window,width=500, height=270, bg="black")
canvas2.place(x=5,y=380) 

canvas3 = Canvas(window,width=280, height=530, bg="green")
canvas3.place(x=515,y=120)

l1=tk.Label(canvas1,text="Digit",font=('Algerian',20))
l1.place(x=5,y=0)

t1=tk.Entry(canvas1,width=20, border=5)
t1.place(x=150, y=7)

def screen_capture():
    import pyscreenshot as ImageGrab
    import time
    import os
    os.startfile("C:/ProgramData/Microsoft/Windows/Start Menu/Programs/Accessories/Paint")
    s1=t1.get()
    os.chdir("E:/DS and ML/Untitled Folder/Untitled Folder/captured_images")
    os.mkdir(s1)
    os.chdir("E:/DS and ML/Untitled Folder/Untitled Folder/")

    images_folder="captured_images/"+s1+"/"
    time.sleep(15)
    for i in range(0,5):
        time.sleep(8)
        im=ImageGrab.grab(bbox=(60,170,400,550)) #x1,y1,x2,y2
        print("saved......",i)
        im.save(images_folder+str(i)+'.png')
        print("clear screen now and redraw now........")
    messagebox.showinfo("Result","Capturing screen is completed!!")
    
b1=tk.Button(canvas1,text="1. Capture the screen", font=('Algerian',15),bg="orange",fg="black",command=screen_capture)
b1.place(x=5, y=50)

def generate_dataset():
    import cv2
    import csv
    import glob

    header  =["label"]
    for i in range(0,784):
        header.append("pixel"+str(i))
    with open('dataset.csv', 'a') as f:
        writer = csv.writer(f)
        writer.writerow(header)

    for label in range(10):
        dirList = glob.glob("captured_images/"+str(label)+"/*.png")

        for img_path in dirList:
            im= cv2.imread(img_path)
            im_gray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
            im_gray = cv2.GaussianBlur(im_gray,(15,15), 0)
            roi= cv2.resize(im_gray,(28,28), interpolation=cv2.INTER_AREA)

            data=[]
            data.append(label)
            rows, cols = roi.shape

            ## Add pixel one by one into data array
            for i in range(rows):
                for j in range(cols):
                    k =roi[i,j]
                    if k>100:
                        k=1
                    else:
                        k=0
                    data.append(k)
            with open('dataset.csv', 'a') as f:
                writer = csv.writer(f)
                writer.writerow(data)
    messagebox.showinfo("Result","Generating dataset is completed!!")
    
b2=tk.Button(canvas1,text="2. Generate dataset", font=('Algerian',15),bg="pink",fg="blue",command=generate_dataset)
b2.place(x=5, y=100)

def train_save_accuracy():
    import pandas as pd
    from sklearn.utils import shuffle
    data  =pd.read_csv('dataset.csv')
    data=shuffle(data)
    X = data.drop(["label"],axis=1)
    Y= data["label"]
    from sklearn.model_selection import train_test_split
    train_x,test_x,train_y,test_y = train_test_split(X,Y, test_size = 0.2)
    import joblib
    from sklearn.svm import SVC
    classifier=SVC(kernel="linear", random_state=6)
    classifier.fit(train_x,train_y)
    joblib.dump(classifier, "model/digit_recognizer")
    from sklearn import metrics
    prediction=classifier.predict(test_x)
    acc=metrics.accuracy_score(prediction, test_y)
    messagebox.showinfo("Result",f"Your accuracy is {acc}")
    
b3=tk.Button(canvas1,text="3. Train the model and calculate accuracy", font=('Algerian',15),bg="green",fg="white",command=train_save_accuracy)
b3.place(x=5, y=150)

def prediction():
    import joblib
    import cv2
    import numpy as np #pip install numpy
    import time
    import pyscreenshot as ImageGrab
    
    
    canvas3 = Canvas(window,width=280, height=530,bg="green")
    canvas3.place(x=515,y=120)
    
    model=joblib.load("model/digit_recognizer")
    

    #while True:
    img=ImageGrab.grab(bbox=(130,500,500,700))
#130,500,500,700
    img.save("paint.png")
#     save()
    im = cv2.imread("paint.png")
    
    
    
    load = Image.open("paint.png")
    load = load.resize((280,280))
    photo = ImageTk.PhotoImage(load)
    # labels can be text or images
    
    img = Label(canvas3, image=photo, width=280,height=280)
    img.image = photo
    img.place(x=0, y=0)
    
    im_gray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
    im_gray  =cv2.GaussianBlur(im_gray, (15,15), 0)

    #Threshold the image
    ret, im_th = cv2.threshold(im_gray,100, 255, cv2.THRESH_BINARY)
    roi = cv2.resize(im_th, (28,28), interpolation  =cv2.INTER_AREA)

    rows,cols=roi.shape

    X = []

    ## Add pixel one by one into data array
    for i in range(rows):
        for j in range(cols):
            k = roi[i,j]
            if k>100:
                k=1
            else:
                k=0
            X.append(k)

    predictions  =model.predict([X])
    
    al = tk.Label(canvas3, text="Prediction=", font=("Algerian",20))
    al.place(x=5,y=350)
    bl = tk.Label(canvas3, text=predictions[0], font=("Algerian",20))
    bl.place(x=200,y=350)
    
    
    

b4=tk.Button(canvas1,text="4. Live prediction", font=('Algerian',15),bg="white",fg="red",command=prediction)
b4.place(x=5, y=200)

# def save():
#     filename = f'paint.png'
#     image1.save(filename)

def activate_paint(e):
    global lastx, lasty
    canvas2.bind('<B1-Motion>', paint)
    lastx, lasty = e.x, e.y


def paint(e):
    global lastx, lasty
    x, y = e.x, e.y
    canvas2.create_line((lastx, lasty, x, y), width=40,fill="white")
    lastx,lasty=x,y
#     draw.line((lastx, lasty, x, y), fill='white', width=40)
#     lastx, lasty = x, y

    
# image1 = PIL.Image.new('RGB', (500,270))
# draw = ImageDraw.Draw(image1)

canvas2.bind('<1>', activate_paint)

def clear():
    canvas2.delete("all")
    
btn = tk.Button(canvas2,text="clear", fg="white", bg="green",command=clear)
btn.place(x=0,y=0)




#window.after(5000, window.destroy)



    

window.geometry("800x680")
window.mainloop()

# %% [markdown]
# # Explanation

# %%
import tkinter as tk
from tkinter import *

# %%
window=tk.Tk()
window.title('Project')

canvas1 = Canvas(window,width=500, height=250, bg='ivory')
canvas1.place(x=5,y=120)                

canvas2 = Canvas(window,width=500, height=270, bg="black")
canvas2.place(x=5,y=380) 

canvas3 = Canvas(window,width=280, height=530, bg="green")
canvas3.place(x=515,y=120)

window.geometry('800x680')
window.mainloop()

# %%
window=tk.Tk()
window.title('Project')

header = tk.Button(window, width=115, height=7, bg="red")
header.place(x=5,y=0)

canvas1 = Canvas(window,width=500, height=250, bg='ivory')
canvas1.place(x=5,y=120)                

canvas2 = Canvas(window,width=500, height=270, bg="black")
canvas2.place(x=5,y=380) 

canvas3 = Canvas(window,width=280, height=530, bg="green")
canvas3.place(x=515,y=120)

window.geometry('800x680')
window.mainloop()

# %%
from PIL import Image,ImageTk
window=tk.Tk()
window.title('Project')

load = Image.open("header.png")
photo = ImageTk.PhotoImage(load)

header = tk.Button(window, image=photo)
header.place(x=5,y=0)

canvas1 = Canvas(window,width=500, height=250, bg='ivory')
canvas1.place(x=5,y=120)                

canvas2 = Canvas(window,width=500, height=270, bg="black")
canvas2.place(x=5,y=380) 

canvas3 = Canvas(window,width=280, height=530, bg="green")
canvas3.place(x=515,y=120)

window.geometry('800x680')
window.mainloop()

# %%
from PIL import Image,ImageTk
window=tk.Tk()
window.title('Project')

load = Image.open("header.png")
photo = ImageTk.PhotoImage(load)

header = tk.Button(window, image=photo)
header.place(x=5,y=0)

canvas1 = Canvas(window,width=500, height=250, bg='ivory')
canvas1.place(x=5,y=120)                

canvas2 = Canvas(window,width=500, height=270, bg="black")
canvas2.place(x=5,y=380) 

canvas3 = Canvas(window,width=280, height=530, bg="green")
canvas3.place(x=515,y=120)

l1 = tk.Label(canvas1,text="Label", font=('Algerian',20))
l1.place(x=5,y=5)

t1 = tk.Entry(canvas1, width=20, bd=5)
t1.place(x=150,y=5)

b1 = tk.Button(canvas1, text="Submit", font=('Algerian',20))
b1.place(x=50,y=100)

window.geometry('800x680')
window.mainloop()

# %%
from PIL import Image,ImageTk
window=tk.Tk()
window.title('Project')
window.resizable(0,0)

load = Image.open("header.png")
photo = ImageTk.PhotoImage(load)

header = tk.Button(window, image=photo)
header.place(x=5,y=0)

canvas1 = Canvas(window,width=500, height=250, bg='ivory')
canvas1.place(x=5,y=120)                

canvas2 = Canvas(window,width=500, height=270, bg="black")
canvas2.place(x=5,y=380) 

canvas3 = Canvas(window,width=280, height=530, bg="green")
canvas3.place(x=515,y=120)

l1 = tk.Label(canvas1,text="Label", font=('Algerian',20))
l1.place(x=5,y=5)

t1 = tk.Entry(canvas1, width=20, bd=5)
t1.place(x=150,y=5)

b1 = tk.Button(canvas1, text="Submit", font=('Algerian',20))
b1.place(x=50,y=100)

load2 = Image.open("image.png")
photo2 = ImageTk.PhotoImage(load2)

canvas2.create_image(250,135, image=photo2)

window.geometry('800x680')
window.mainloop()
